# %% [markdown]
# ![image.png](attachment:02e11f2a-9cee-49fd-9d8d-6f9c30cdd1bc.png)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![image.png](attachment:f7e52961-7ad4-4e1a-925d-49ab7a8ac498.png)

# %% [markdown]
# ##### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# * List popular languages for Data Science
# * List data science libraries
# * List data Science Tools
# * Create a code cell to multiply and add numbers

# %% [markdown]
# ![image.png](attachment:00d3c2dc-b010-447c-b8ea-6607dcbdf924.png)

# %% [markdown]
# ##### Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. Java
# 3. SQL
# 4. R
# 5. C

# %% [markdown]
# ![image.png](attachment:fc3e63f8-679c-4b42-b666-2069a5e2b628.png)

# %% [markdown]
# ##### Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. Pandas
# 3. Plotly
# 4. Scikit-learn

# %% [markdown]
# ![image.png](attachment:70ff8364-6d3a-44e9-8aad-866f3dc164bd.png)

# %% [markdown]
# | Data Science Tools |
# | -------------|
# | Jupyter Notebook |
# | RStudio |
# | VS Code |

# %% [markdown]
# ![image.png](attachment:b95611de-c70b-4c01-be21-411e0ab0b921.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# ![image.png](attachment:e10ea87e-8990-4132-a373-b2918a72b6f3.png)

# %%
# This a simple arithmetic expression to multiply then add integers.
(3 * 4) + 5
# Out:
# 17

# %% [markdown]
# ![image.png](attachment:9b17b742-8373-44ae-b28d-eb33230661ba.png)

# %%
# This will convert 200 minutes to hours by diving by 60.
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![image.png](attachment:1ea8ffed-8080-4973-bec0-d100e28603ac.png)

# %% [markdown]
# ![image.png](attachment:95e38b3e-ecdf-42f6-ba5b-d1f197469693.png)

# %% [markdown]
# ## Author
# PURUSHOTHAM KOTHAKOTA
